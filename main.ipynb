# %%
# coding: utf-8
import importlib as imp
import data as Data
import util as Util
import alg1 as Alg1
import alg2 as Alg2
import alg3 as Alg3
import copy
import plot as plot
from data import savecsv, getpalloc
import graph as Graph

# 读取和处理数据
Table, flight = Data.data_process()

#建立各需要的图
# 总冲突图
graph = Graph.GraphTP(Table['Puck'], Table['Gate'])
#graphT = Graph.GraphT(Table['Puck'])
# 航班与登机口间的冲突图
graphP = Graph.GraphP(Table['Puck'], Table['Gate'])
# 航班与登机口兼容性冲突图
graphPi = Graph.GraphP(Table['Puck'], Table['Gate'], inv=True)
# 统计图中的信息
Graph.statistic(Table['Puck'], Table['Gate'])
# Out:
# Import util module at 2018-09-20 10:41:14.328253
# Import data module at 2018-09-20 10:41:14.328611
# Import Alg1 module at 2018-09-20 10:41:14.329755
# Import alg2 module at 2018-09-20 10:41:14.330461
# Import alg2 module at 2018-09-20 10:41:14.331047
# Import graph module at 2018-09-20 10:41:14.332058
# Loading data from ./InputData.xlsx
# Removing the data out of the time range ...
# Constructing Tables ...
# Getting in/out flight dicts ...
# Building time-type-conflict Graph ...
# Building type-conflict Graph ...
# Building type-nonconflict Graph ...
# Gate classes:
#   I|DIW : 1	 Compatible punks: 44
#   D|DN  : 35	 Compatible punks: 145
#   DI|DIW: 3	 Compatible punks: 49
#   D|DW  : 2	 Compatible punks: 0
#   DI|DIN: 2	 Compatible punks: 254
#   D|DIN : 2	 Compatible punks: 190
#   DI|DN : 2	 Compatible punks: 181
#   I|IN  : 4	 Compatible punks: 28
#   I|IW  : 17	 Compatible punks: 39
#   DI|IW : 1	 Compatible punks: 44
#   Count: 69, Classes: 10
# -----------
#   DDW: 6
#   DIW: 4
#   IIN: 8
#   IIW: 22
#   IDW: 4
#   DDN: 41
#   DIN: 4
#   IDN: 4
#   Count: 93, Classes: 8
# Puck classes:
#   DIW:   5	 Compatible gates: 4
#   IIN:  28	 Compatible gates: 6
#   IIW:  39	 Compatible gates: 22
#   IDW:   5	 Compatible gates: 4
#   DDN: 145	 Compatible gates: 41
#   DIN:  45	 Compatible gates: 4
#   IDN:  36	 Compatible gates: 4
#   Count: 303, Classes: 7

# %%
# 问题一步骤A
alloc1A, remain1A = Alg1.algorithm1A(Table, graph, graphPi)
Util.check_allocation(Table, alloc1A, remain1A)
# 问题一步骤B
alloc1B, remain1B = Alg1.algorithm1B(Table, graph, graphPi, alloc1A, remain1A)
# 问题一步骤c
alloc1 = Alg1.algorithm1C(Table, graph, graphPi, alloc1B)
#Util.check_allocation(Table, alloc1C)
# Out:
# Round 1
#   allocate gate S29 with 0 pucks
#   remain 68 gates and 303 pucks
# Round 2
#   allocate gate S30 with 0 pucks
#   remain 67 gates and 303 pucks
# Round 3
#   allocate gate S12 with 6 pucks
#   remain 66 gates and 297 pucks
# Round 4
#   allocate gate S11 with 6 pucks
#   remain 65 gates and 291 pucks
# Round 5
#   allocate gate T1 with 4 pucks
#   remain 64 gates and 287 pucks
# Round 6
#   allocate gate S13 with 3 pucks
#   remain 63 gates and 284 pucks
# Round 7
#   allocate gate S39 with 4 pucks
#   remain 62 gates and 280 pucks
# Round 8
#   allocate gate S34 with 4 pucks
#   remain 61 gates and 276 pucks
# Round 9
#   allocate gate T26 with 3 pucks
#   remain 60 gates and 273 pucks
# Round 10
#   allocate gate T4 with 3 pucks
#   remain 59 gates and 270 pucks
# Round 11
#   allocate gate S41 with 3 pucks
#   remain 58 gates and 267 pucks
# Round 12
#   allocate gate S35 with 2 pucks
#   remain 57 gates and 265 pucks
# Round 13
#   allocate gate T28 with 2 pucks
#   remain 56 gates and 263 pucks
# Round 14
#   allocate gate T3 with 2 pucks
#   remain 55 gates and 261 pucks
# Round 15
#   allocate gate S37 with 2 pucks
#   remain 54 gates and 259 pucks
# Round 16
#   allocate gate T27 with 2 pucks
#   remain 53 gates and 257 pucks
# Round 17
#   allocate gate S31 with 2 pucks
#   remain 52 gates and 255 pucks
# Round 18
#   allocate gate S40 with 2 pucks
#   remain 51 gates and 253 pucks
# Round 19
#   allocate gate S36 with 2 pucks
#   remain 50 gates and 251 pucks
# Round 20
#   allocate gate T2 with 2 pucks
#   remain 49 gates and 249 pucks
# Round 21
#   allocate gate S33 with 2 pucks
#   remain 48 gates and 247 pucks
# Round 22
#   allocate gate S32 with 1 pucks
#   remain 47 gates and 246 pucks
# Round 23
#   allocate gate S38 with 1 pucks
#   remain 46 gates and 245 pucks
# Round 24
#   allocate gate T5 with 3 pucks
#   remain 45 gates and 242 pucks
# Round 25
#   allocate gate T25 with 3 pucks
#   remain 44 gates and 239 pucks
# Round 26
#   allocate gate T6 with 3 pucks
#   remain 43 gates and 236 pucks
# Round 27
#   allocate gate T24 with 1 pucks
#   remain 42 gates and 235 pucks
# Round 28
#   allocate gate T23 with 0 pucks
#   remain 41 gates and 235 pucks
# Round 29
#   allocate gate S19 with 7 pucks
#   remain 40 gates and 228 pucks
# Round 30
#   allocate gate S4 with 6 pucks
#   remain 39 gates and 222 pucks
# Round 31
#   allocate gate S16 with 6 pucks
#   remain 38 gates and 216 pucks
# Round 32
#   allocate gate T13 with 6 pucks
#   remain 37 gates and 210 pucks
# Round 33
#   allocate gate S25 with 6 pucks
#   remain 36 gates and 204 pucks
# Round 34
#   allocate gate S1 with 6 pucks
#   remain 35 gates and 198 pucks
# Round 35
#   allocate gate S23 with 5 pucks
#   remain 34 gates and 193 pucks
# Round 36
#   allocate gate S9 with 5 pucks
#   remain 33 gates and 188 pucks
# Round 37
#   allocate gate S26 with 5 pucks
#   remain 32 gates and 183 pucks
# Round 38
#   allocate gate S3 with 5 pucks
#   remain 31 gates and 178 pucks
# Round 39
#   allocate gate S2 with 6 pucks
#   remain 30 gates and 172 pucks
# Round 40
#   allocate gate S20 with 5 pucks
#   remain 29 gates and 167 pucks
# Round 41
#   allocate gate S14 with 4 pucks
#   remain 28 gates and 163 pucks
# Round 42
#   allocate gate T15 with 4 pucks
#   remain 27 gates and 159 pucks
# Round 43
#   allocate gate S5 with 4 pucks
#   remain 26 gates and 155 pucks
# Round 44
#   allocate gate T14 with 4 pucks
#   remain 25 gates and 151 pucks
# Round 45
#   allocate gate S18 with 3 pucks
#   remain 24 gates and 148 pucks
# Round 46
#   allocate gate T18 with 3 pucks
#   remain 23 gates and 145 pucks
# Round 47
#   allocate gate S27 with 3 pucks
#   remain 22 gates and 142 pucks
# Round 48
#   allocate gate S17 with 4 pucks
#   remain 21 gates and 138 pucks
# Round 49
#   allocate gate S7 with 3 pucks
#   remain 20 gates and 135 pucks
# Round 50
#   allocate gate T17 with 3 pucks
#   remain 19 gates and 132 pucks
# Round 51
#   allocate gate S6 with 2 pucks
#   remain 18 gates and 130 pucks
# Round 52
#   allocate gate S28 with 2 pucks
#   remain 17 gates and 128 pucks
# Round 53
#   allocate gate T10 with 2 pucks
#   remain 16 gates and 126 pucks
# Round 54
#   allocate gate T12 with 2 pucks
#   remain 15 gates and 124 pucks
# Round 55
#   allocate gate S15 with 2 pucks
#   remain 14 gates and 122 pucks
# Round 56
#   allocate gate S8 with 2 pucks
#   remain 13 gates and 120 pucks
# Round 57
#   allocate gate T11 with 2 pucks
#   remain 12 gates and 118 pucks
# Round 58
#   allocate gate T19 with 2 pucks
#   remain 11 gates and 116 pucks
# Round 59
#   allocate gate S24 with 2 pucks
#   remain 10 gates and 114 pucks
# Round 60
#   allocate gate S21 with 2 pucks
#   remain 9 gates and 112 pucks
# Round 61
#   allocate gate T16 with 2 pucks
#   remain 8 gates and 110 pucks
# Round 62
#   allocate gate S10 with 2 pucks
#   remain 7 gates and 108 pucks
# Round 63
#   allocate gate S22 with 2 pucks
#   remain 6 gates and 106 pucks
# Round 64
#   allocate gate T8 with 6 pucks
#   remain 5 gates and 100 pucks
# Round 65
#   allocate gate T9 with 5 pucks
#   remain 4 gates and 95 pucks
# Round 66
#   allocate gate T21 with 6 pucks
#   remain 3 gates and 89 pucks
# Round 67
#   allocate gate T20 with 5 pucks
#   remain 2 gates and 84 pucks
# Round 68
#   allocate gate T22 with 6 pucks
#   remain 1 gates and 78 pucks
# Round 69
#   allocate gate T7 with 5 pucks
#   remain 0 gates and 73 pucks
# ========================================
# Gate S39 [I|IW]: 4
# Gate S34 [I|IW]: 4
# Gate S8 [D|DN]: 2
# Gate T5 [I|DIW]: 3
# Gate S19 [D|DN]: 7
# Gate S4 [D|DN]: 6
# Gate S18 [D|DN]: 3
# Gate S16 [D|DN]: 6
# Gate T4 [I|IW]: 3
# Gate T13 [D|DN]: 6
# Gate S36 [I|IW]: 2
# Gate T8 [DI|DN]: 6
# Gate S35 [I|IW]: 2
# Gate T7 [DI|DIN]: 5
# Gate T28 [I|IW]: 2
# Gate S23 [D|DN]: 5
# Gate S9 [D|DN]: 5
# Gate T6 [DI|DIW]: 3
# Gate T22 [DI|DIN]: 6
# Gate T10 [D|DN]: 2
# Gate S2 [D|DN]: 6
# Gate S20 [D|DN]: 5
# Gate T1 [I|IN]: 4
# Gate S14 [D|DN]: 4
# Gate T15 [D|DN]: 4
# Gate S37 [I|IW]: 2
# Gate S5 [D|DN]: 4
# Gate T14 [D|DN]: 4
# Gate S26 [D|DN]: 5
# Gate T9 [DI|DN]: 5
# Gate T18 [D|DN]: 3
# Gate T27 [I|IW]: 2
# Gate S17 [D|DN]: 4
# Gate S3 [D|DN]: 5
# Gate S40 [I|IW]: 2
# Gate T20 [D|DIN]: 5
# Gate S38 [I|IW]: 1
# Gate S11 [I|IN]: 6
# Gate S6 [D|DN]: 2
# Gate S28 [D|DN]: 2
# Gate T2 [I|IW]: 2
# Gate T21 [D|DIN]: 6
# Gate T24 [DI|DIW]: 1
# Gate S22 [D|DN]: 2
# Gate S27 [D|DN]: 3
# Gate S24 [D|DN]: 2
# Gate T25 [DI|IW]: 3
# Gate S33 [I|IW]: 2
# Gate T16 [D|DN]: 2
# Gate T26 [I|IW]: 3
# Gate T11 [D|DN]: 2
# Gate S7 [D|DN]: 3
# Gate T17 [D|DN]: 3
# Gate S31 [I|IW]: 2
# Gate T3 [I|IW]: 2
# Gate S25 [D|DN]: 6
# Gate S32 [I|IW]: 1
# Gate T12 [D|DN]: 2
# Gate S13 [I|IN]: 3
# Gate T19 [D|DN]: 2
# Gate S41 [I|IW]: 3
# Gate S21 [D|DN]: 2
# Gate S1 [D|DN]: 6
# Gate S10 [D|DN]: 2
# Gate S12 [I|IN]: 6
# Gate S15 [D|DN]: 2
#
# Total rounds: 69
# Used gates: 66
# Allocated pucks: 230
# Remain pucks: 73
# Number of pucks: 303
# Score: 197.0
# ========================================
# No conflict found!
# Total allocation: 230
# Real Total allocation: 230
# Used gates: 66
# No wrong remain puck!
# ========================================
# ========================================
# No conflict found!
# Total allocation: 230
# Real Total allocation: 230
# Used gates: 66
# ========================================
#   Allocation success: PK417 -> S19
#   Allocation success: PK484 -> S4
#   Allocation success: PK491 -> S4
#   Allocation success: PK478 -> S4
#   Allocation success: PK181 -> S16
# Success allocation: 5
# Remain 68 pucks
# ========================================
# No conflict found!
# Total allocation: 235
# Real Total allocation: 235
# Used gates: 66
# ========================================
# ========================================
# No conflict found!
# Total allocation: 235
# Real Total allocation: 235
# Used gates: 66
# ========================================
# 1/69
# 2/69
# 3/69
# 4/69
# 5/69
# 6/69
# 7/69
#   Allocation success: PK349 -> S36
# 8/69
#   Allocation success: PK377 -> S35
# 9/69
#   Allocation success: PK400 -> T28
# 10/69
# 11/69
#   Allocation success: PK347 -> S37
# 12/69
#   Allocation success: PK328 -> S40
# 13/69
# 14/69
# 15/69
#   Allocation success: PK382 -> T2
# 16/69
# 17/69
#   Allocation success: PK373 -> S33
# 18/69
# 19/69
#   Allocation success: PK340 -> S31
# 20/69
#   Allocation success: PK333 -> T3
# 21/69
#   Allocation success: PK363 -> T27
# 22/69
# 23/69
# 24/69
# 25/69
#   Allocation success: PK108 -> T4
#   Allocation success: PK308 -> T4
# 26/69
#   Allocation success: PK331 -> T24
# 27/69
#   Allocation success: PK312 -> S18
# 28/69
#   Allocation success: PK452 -> T24
#   Allocation success: PK374 -> T24
# 29/69
#   Allocation success: PK297 -> S22
# 30/69
#   Allocation success: PK106 -> T24
#   Allocation success: PK352 -> T24
# 31/69
#   Allocation success: PK104 -> T26
#   Allocation success: PK338 -> T26
# 32/69
#   Allocation success: PK266 -> T11
# 33/69
#   Allocation success: PK291 -> S7
# 34/69
#   Allocation success: PK272 -> T17
# 35/69
#   Allocation success: PK117 -> S19
# 36/69
# 37/69
#   Allocation success: PK107 -> S41
#   Allocation success: PK336 -> S41
# 38/69
#   Allocation success: PK264 -> S15
# 39/69
#   Allocation success: PK129 -> T26
#   Allocation success: PK304 -> T26
#   Allocation success: PK370 -> S34
# 40/69
#   Allocation success: PK131 -> T26
#   Allocation success: PK411 -> T26
#   Allocation success: PK316 -> S34
# 41/69
# 42/69
#   Allocation success: PK298 -> S22
#   Allocation success: PK254 -> S14
# 43/69
#   Allocation success: PK182 -> T15
#   Allocation success: PK282 -> S22
# 44/69
#   Allocation success: PK310 -> S5
#   Allocation success: PK136 -> S25
# 45/69
#   Allocation success: PK299 -> T14
#   Allocation success: PK147 -> T14
#   Allocation success: PK501 -> T14
# 46/69
#   Allocation success: PK307 -> S22
#   Allocation success: PK267 -> T18
# 47/69
#   Allocation success: PK279 -> S17
# 48/69
#   Allocation success: PK435 -> S25
#   Allocation success: PK259 -> S22
#   Allocation success: PK187 -> S22
# 49/69
#   Allocation success: PK315 -> S21
#   Allocation success: PK170 -> S21
# 50/69
#   Allocation success: PK323 -> S16
#   Allocation success: PK277 -> S4
#   Allocation success: PK362 -> S4
# 51/69
#   Allocation success: PK309 -> S16
#   Allocation success: PK276 -> S16
#   Allocation success: PK348 -> S16
# 52/69
# 53/69
#   Allocation success: PK438 -> S25
#   Allocation success: PK305 -> S23
#   Allocation success: PK188 -> S23
# 54/69
#   Allocation success: PK437 -> S25
#   Allocation success: PK306 -> S26
#   Allocation success: PK150 -> S26
# 55/69
#   Allocation success: PK429 -> S1
#   Allocation success: PK326 -> S20
#   Allocation success: PK443 -> S20
# 56/69
#   Allocation success: PK431 -> S25
#   Allocation success: PK179 -> S9
#   Allocation success: PK294 -> S9
# 57/69
# 58/69
#   Allocation success: PK430 -> S1
#   Allocation success: PK325 -> S3
#   Allocation success: PK446 -> S25
# 59/69
# 60/69
#   Allocation success: PK440 -> S16
#   Allocation success: PK283 -> S4
#   Allocation success: PK192 -> S4
# 61/69
#   Allocation success: PK300 -> T13
#   Allocation success: PK447 -> T13
#   Allocation success: PK273 -> T13
#   Allocation success: PK360 -> T13
# 62/69
# 63/69
# 64/69
#   Allocation success: PK428 -> S1
#   Allocation success: PK288 -> S2
#   Allocation success: PK335 -> S2
#   Allocation success: PK175 -> S2
# 65/69
#   Allocation success: PK149 -> S12
#   Allocation success: PK274 -> S13
# 66/69
# 67/69
#   Allocation success: PK439 -> S1
#   Allocation success: PK173 -> S25
#   Allocation success: PK284 -> S25
#   Allocation success: PK320 -> S25
# 68/69
#   Allocation success: PK433 -> S1
#   Allocation success: PK293 -> S1
#   Allocation success: PK180 -> S1
#   Allocation success: PK339 -> S1
# 69/69
#   Allocation success: PK144 -> S12
#
# Total reduced gates: 0
# ========================================
# No conflict found!
# Total allocation: 235
# Real Total allocation: 235
# Used gates: 66
# ========================================

# %%
imp.reload(Alg2)
# 问题二算法
alloc2A = Alg2.algorithmA(Table, flight, graph, graphPi, alloc1)
alloc2 = Alg2.algorithmB(Table, flight, graph, graphPi, alloc2A)
# Out:
# Import alg2 module at 2018-09-20 10:42:01.857141
# ========================================
# No conflict found!
# Total allocation: 235
# Real Total allocation: 235
# Used gates: 66
# ========================================
# 480815
# 1/69
#   Allocation success: PK468 -> S39
#   Reduced cost: PK468 480815
#   Allocation success: PK370 -> S39
#   Reduced cost: PK370 480815
#   Allocation success: PK129 -> S39
#   Reduced cost: PK129 480815
#   Allocation success: PK304 -> S39
#   Reduced cost: PK304 480815
# 2/69
#   Allocation success: PK131 -> S39
#   Reduced cost: PK131 480815
#   Allocation success: PK461 -> S39
#   Reduced cost: PK461 480815
#   Allocation success: PK411 -> S39
#   Reduced cost: PK411 480815
# 3/69
#   Allocation success: PK117 -> S19
#   Reduced cost: PK117 480815
#   Allocation success: PK486 -> S4
#   Reduced cost: PK486 480815
#   Allocation success: PK364 -> S19
#   Reduced cost: PK364 480815
# 4/69
#   Allocation success: PK117 -> S19
#   Reduced cost: PK117 480815
#   Allocation success: PK490 -> S19
#   Reduced cost: PK490 480815
#   Allocation success: PK364 -> S19
#   Reduced cost: PK364 480815
#   Allocation success: PK440 -> S19
#   Reduced cost: PK440 480815
#   Allocation success: PK323 -> S19
#   Reduced cost: PK323 480815
#   Allocation success: PK283 -> S19
#   Reduced cost: PK283 480815
# 5/69
#   Allocation success: PK417 -> S19
#   Reduced cost: PK417 480815
#   Allocation success: PK486 -> S19
#   Reduced cost: PK486 480815
#   Allocation success: PK192 -> S19
#   Reduced cost: PK192 480815
#   Allocation success: PK277 -> S19
#   Reduced cost: PK277 480815
# 6/69
#   Allocation success: PK181 -> S19
#   Reduced cost: PK181 480815
#   Allocation success: PK415 -> S16
#   Reduced cost: PK415 480815
#   Allocation success: PK362 -> S16
#   Reduced cost: PK362 480815
#   Allocation success: PK276 -> S4
#   Reduced cost: PK276 480815
#   Allocation success: PK309 -> S19
#   Reduced cost: PK309 480815
# 7/69
#   Allocation success: PK108 -> S34
#   Reduced cost: PK108 480815
#   Allocation success: PK308 -> T23
#   Reduced cost: PK308 480815
#   Allocation success: PK464 -> S34
#   Reduced cost: PK464 480815
# 8/69
#   Allocation success: PK447 -> S19
#   Reduced cost: PK447 480815
#   Allocation success: PK476 -> S4
#   Reduced cost: PK476 480815
#   Allocation success: PK300 -> S19
#   Reduced cost: PK300 480815
#   Allocation success: PK360 -> S19
#   Reduced cost: PK360 480815
#   Allocation success: PK273 -> S19
#   Reduced cost: PK273 480815
#   Allocation success: PK419 -> S19
#   Reduced cost: PK419 480815
# 9/69
# 10/69
#   Allocation success: PK459 -> T8
#   Reduced cost: PK459 480815
#   Allocation success: PK479 -> S19
#   Reduced cost: PK479 480815
#   Allocation success: PK375 -> T7
#   Reduced cost: PK375 480815
#   Allocation success: PK427 -> T8
#   Reduced cost: PK427 480815
#   Allocation success: PK285 -> T7
#   Reduced cost: PK285 480815
# 11/69
#   Allocation success: PK089 -> S39
#   Reduced cost: PK089 480815
#   Allocation success: PK377 -> S39
#   Reduced cost: PK377 480815
# 12/69
#   Allocation success: PK400 -> S39
#   Reduced cost: PK400 480815
#   Allocation success: PK208 -> S34
#   Reduced cost: PK208 480815
# 13/69
#   Allocation success: PK484 -> S19
#   Reduced cost: PK484 480815
#   Allocation success: PK188 -> S19
#   Reduced cost: PK188 480815
#   Allocation success: PK438 -> T13
#   Reduced cost: PK438 480815
#   Allocation success: PK305 -> S4
#   Reduced cost: PK305 480815
#   Allocation success: PK367 -> S19
#   Reduced cost: PK367 480815
# 14/69
#   Allocation success: PK449 -> S34
#   Reduced cost: PK449 480815
#   Allocation success: PK328 -> S34
#   Reduced cost: PK328 480815
# 15/69
#   Allocation success: PK489 -> S4
#   Reduced cost: PK489 480815
#   Allocation success: PK306 -> S4
#   Reduced cost: PK306 480815
#   Allocation success: PK150 -> S4
#   Reduced cost: PK150 480815
#   Allocation success: PK437 -> S4
#   Reduced cost: PK437 480815
#   Allocation success: PK356 -> S19
#   Reduced cost: PK356 480815
# 16/69
#   Allocation success: PK331 -> T24
#   Reduced cost: PK331 480815
#   Allocation success: PK151 -> T24
#   Reduced cost: PK151 480815
#   Allocation success: PK280 -> T24
#   Reduced cost: PK280 480815
# 17/69
#   Allocation success: PK262 -> T22
#   Reduced cost: PK262 480815
#   Allocation success: PK444 -> T22
#   Reduced cost: PK444 480815
#   Allocation success: PK281 -> T22
#   Reduced cost: PK281 480815
#   Allocation success: PK330 -> T22
#   Reduced cost: PK330 480815
#   Allocation success: PK432 -> T22
#   Reduced cost: PK432 480815
#   Allocation success: PK375 -> T22
#   Reduced cost: PK375 480815
# 18/69
#   Allocation success: PK441 -> S28
#   Reduced cost: PK441 480815
#   Allocation success: PK392 -> S19
#   Reduced cost: PK392 480815
# 19/69
#   Allocation success: PK175 -> S4
#   Reduced cost: PK175 480815
#   Allocation success: PK493 -> S4
#   Reduced cost: PK493 480815
#   Allocation success: PK428 -> S1
#   Reduced cost: PK428 480815
#   Allocation success: PK376 -> S4
#   Reduced cost: PK376 480815
#   Allocation success: PK288 -> S4
#   Reduced cost: PK288 480815
#   Allocation success: PK335 -> S19
#   Reduced cost: PK335 480815
# 20/69
#   Allocation success: PK414 -> S19
#   Reduced cost: PK414 480815
#   Allocation success: PK168 -> T19
#   Reduced cost: PK168 480815
# 21/69
#   Allocation success: PK380 -> S4
#   Reduced cost: PK380 480815
#   Allocation success: PK443 -> S19
#   Reduced cost: PK443 480815
#   Allocation success: PK326 -> S19
#   Reduced cost: PK326 480815
#   Allocation success: PK256 -> S4
#   Reduced cost: PK256 480815
#   Allocation success: PK429 -> S19
#   Reduced cost: PK429 480815
# 22/69
#   Allocation success: PK298 -> S4
#   Reduced cost: PK298 480815
#   Allocation success: PK254 -> S4
#   Reduced cost: PK254 480815
#   Allocation success: PK442 -> S19
#   Reduced cost: PK442 480815
#   Allocation success: PK408 -> S19
#   Reduced cost: PK408 480815
# 23/69
#   Allocation success: PK412 -> T15
#   Reduced cost: PK412 480815
#   Allocation success: PK500 -> S19
#   Reduced cost: PK500 480815
#   Allocation success: PK182 -> S4
#   Reduced cost: PK182 480815
#   Allocation success: PK282 -> S4
#   Reduced cost: PK282 480815
# 24/69
#   Allocation success: PK347 -> S34
#   Reduced cost: PK347 480815
#   Allocation success: PK159 -> S34
#   Reduced cost: PK159 480815
# 25/69
#   Allocation success: PK310 -> S4
#   Reduced cost: PK310 480815
#   Allocation success: PK403 -> S19
#   Reduced cost: PK403 480815
#   Allocation success: PK498 -> S4
#   Reduced cost: PK498 480815
#   Allocation success: PK136 -> S19
#   Reduced cost: PK136 480815
#   Allocation success: PK348 -> S19
#   Reduced cost: PK348 480815
# 26/69
#   Allocation success: PK399 -> S19
#   Reduced cost: PK399 480815
#   Allocation success: PK299 -> S19
#   Reduced cost: PK299 480815
#   Allocation success: PK147 -> S14
#   Reduced cost: PK147 480815
#   Allocation success: PK501 -> S4
#   Reduced cost: PK501 480815
# 27/69
#   Allocation success: PK312 -> S4
#   Reduced cost: PK312 480815
#   Allocation success: PK197 -> S4
#   Reduced cost: PK197 480815
#   Allocation success: PK410 -> S19
#   Reduced cost: PK410 480815
# 28/69
#   Allocation success: PK294 -> S4
#   Reduced cost: PK294 480815
#   Allocation success: PK254 -> S4
#   Reduced cost: PK254 480815
#   Allocation success: PK442 -> S19
#   Reduced cost: PK442 480815
#   Allocation success: PK396 -> S4
#   Reduced cost: PK396 480815
#   Allocation success: PK339 -> S19
#   Reduced cost: PK339 480815
#   Allocation success: PK431 -> S19
#   Reduced cost: PK431 480815
# 29/69
#   Allocation success: PK404 -> T9
#   Reduced cost: PK404 480815
#   Allocation success: PK296 -> T9
#   Reduced cost: PK296 480815
#   Allocation success: PK353 -> T9
#   Reduced cost: PK353 480815
#   Allocation success: PK467 -> T7
#   Reduced cost: PK467 480815
#   Allocation success: PK270 -> T9
#   Reduced cost: PK270 480815
# 30/69
#   Allocation success: PK151 -> T24
#   Reduced cost: PK151 480815
#   Allocation success: PK374 -> T24
#   Reduced cost: PK374 480815
# 31/69
#   Allocation success: PK155 -> S19
#   Reduced cost: PK155 480815
#   Allocation success: PK424 -> S19
#   Reduced cost: PK424 480815
#   Allocation success: PK267 -> S19
#   Reduced cost: PK267 480815
#   Allocation success: PK307 -> S19
#   Reduced cost: PK307 480815
# 32/69
# 33/69
#   Allocation success: PK477 -> S19
#   Reduced cost: PK477 480815
#   Allocation success: PK279 -> S19
#   Reduced cost: PK279 480815
#   Allocation success: PK425 -> S17
#   Reduced cost: PK425 480815
#   Allocation success: PK346 -> S19
#   Reduced cost: PK346 480815
# 34/69
#   Allocation success: PK446 -> S4
#   Reduced cost: PK446 480815
#   Allocation success: PK414 -> S19
#   Reduced cost: PK414 480815
#   Allocation success: PK325 -> S19
#   Reduced cost: PK325 480815
# 35/69
#   Allocation success: PK259 -> S4
#   Reduced cost: PK259 480815
#   Allocation success: PK306 -> S4
#   Reduced cost: PK306 480815
#   Allocation success: PK187 -> S19
#   Reduced cost: PK187 480815
#   Allocation success: PK435 -> S4
#   Reduced cost: PK435 480815
#   Allocation success: PK383 -> S4
#   Reduced cost: PK383 480815
# 36/69
#   Allocation success: PK258 -> T20
#   Reduced cost: PK258 480815
#   Allocation success: PK177 -> T22
#   Reduced cost: PK177 480815
#   Allocation success: PK420 -> T20
#   Reduced cost: PK420 480815
#   Allocation success: PK286 -> T21
#   Reduced cost: PK286 480815
#   Allocation success: PK341 -> T20
#   Reduced cost: PK341 480815
# 37/69
#   Allocation success: PK274 -> S11
#   Reduced cost: PK274 480815
#   Allocation success: PK409 -> S11
#   Reduced cost: PK409 480815
#   Allocation success: PK358 -> S11
#   Reduced cost: PK358 480815
#   Allocation success: PK314 -> S11
#   Reduced cost: PK314 480815
#   Allocation success: PK149 -> S11
#   Reduced cost: PK149 480815
#   Allocation success: PK455 -> S11
#   Reduced cost: PK455 480815
# 38/69
#   Allocation success: PK349 -> S34
#   Reduced cost: PK349 480815
#   Allocation success: PK454 -> S34
#   Reduced cost: PK454 480815
# 39/69
#   Allocation success: PK102 -> S19
#   Reduced cost: PK102 480815
#   Allocation success: PK407 -> S19
#   Reduced cost: PK407 480815
# 40/69
#   Allocation success: PK387 -> S4
#   Reduced cost: PK387 480815
#   Allocation success: PK145 -> S4
#   Reduced cost: PK145 480815
# 41/69
#   Allocation success: PK471 -> S34
#   Reduced cost: PK471 480815
#   Allocation success: PK382 -> S39
#   Reduced cost: PK382 480815
# 42/69
#   Allocation success: PK258 -> T22
#   Reduced cost: PK258 480815
#   Allocation success: PK436 -> T22
#   Reduced cost: PK436 480815
#   Allocation success: PK378 -> T21
#   Reduced cost: PK378 480815
#   Allocation success: PK337 -> T21
#   Reduced cost: PK337 480815
# 43/69
#   Allocation success: PK308 -> S36
#   Reduced cost: PK308 480815
#   Allocation success: PK487 -> T23
#   Reduced cost: PK487 480815
#   Allocation success: PK106 -> T23
#   Reduced cost: PK106 480815
# 44/69
#   Allocation success: PK297 -> S4
#   Reduced cost: PK297 480815
#   Allocation success: PK423 -> S4
#   Reduced cost: PK423 480815
#   Allocation success: PK174 -> S4
#   Reduced cost: PK174 480815
# 45/69
#   Allocation success: PK193 -> S4
#   Reduced cost: PK193 480815
#   Allocation success: PK418 -> S4
#   Reduced cost: PK418 480815
# 46/69
#   Allocation success: PK445 -> T25
#   Reduced cost: PK445 480815
#   Allocation success: PK352 -> T25
#   Reduced cost: PK352 480815
# 47/69
#   Allocation success: PK373 -> S39
#   Reduced cost: PK373 480815
#   Allocation success: PK094 -> S34
#   Reduced cost: PK094 480815
# 48/69
#   Allocation success: PK369 -> S4
#   Reduced cost: PK369 480815
#   Allocation success: PK473 -> S4
#   Reduced cost: PK473 480815
# 49/69
#   Allocation success: PK338 -> S39
#   Reduced cost: PK338 480815
#   Allocation success: PK461 -> S34
#   Reduced cost: PK461 480815
#   Allocation success: PK104 -> S39
#   Reduced cost: PK104 480815
# 50/69
#   Allocation success: PK287 -> S13
#   Reduced cost: PK287 480815
#   Allocation success: PK391 -> S12
#   Reduced cost: PK391 480815
#   Allocation success: PK475 -> S11
#   Reduced cost: PK475 480815
# 51/69
#   Allocation success: PK280 -> T24
#   Reduced cost: PK280 480815
#   Allocation success: PK374 -> T24
#   Reduced cost: PK374 480815
# 52/69
#   Allocation success: PK394 -> S4
#   Reduced cost: PK394 480815
#   Allocation success: PK191 -> S4
#   Reduced cost: PK191 480815
#   Allocation success: PK266 -> S19
#   Reduced cost: PK266 480815
# 53/69
#   Allocation success: PK448 -> S19
#   Reduced cost: PK448 480815
#   Allocation success: PK291 -> S4
#   Reduced cost: PK291 480815
#   Allocation success: PK413 -> S4
#   Reduced cost: PK413 480815
# 54/69
#   Allocation success: PK398 -> S4
#   Reduced cost: PK398 480815
#   Allocation success: PK195 -> S4
#   Reduced cost: PK195 480815
#   Allocation success: PK272 -> S4
#   Reduced cost: PK272 480815
# 55/69
#   Allocation success: PK456 -> S34
#   Reduced cost: PK456 480815
#   Allocation success: PK340 -> S34
#   Reduced cost: PK340 480815
# 56/69
#   Allocation success: PK333 -> S34
#   Reduced cost: PK333 480815
#   Allocation success: PK460 -> S34
#   Reduced cost: PK460 480815
# 57/69
#   Allocation success: PK453 -> S34
#   Reduced cost: PK453 480815
#   Allocation success: PK363 -> S34
#   Reduced cost: PK363 480815
# 58/69
#   Allocation success: PK478 -> S4
#   Reduced cost: PK478 480815
#   Allocation success: PK440 -> S19
#   Reduced cost: PK440 480815
#   Allocation success: PK406 -> S4
#   Reduced cost: PK406 480815
#   Allocation success: PK320 -> S19
#   Reduced cost: PK320 480815
#   Allocation success: PK284 -> S19
#   Reduced cost: PK284 480815
# 59/69
#   Allocation success: PK457 -> S33
#   Reduced cost: PK457 480815
# 60/69
#   Allocation success: PK482 -> S19
#   Reduced cost: PK482 480815
#   Allocation success: PK395 -> S4
#   Reduced cost: PK395 480815
#   Allocation success: PK276 -> S19
#   Reduced cost: PK276 480815
#   Allocation success: PK309 -> S19
#   Reduced cost: PK309 480815
# 61/69
#   Allocation success: PK287 -> S13
#   Reduced cost: PK287 480815
#   Allocation success: PK334 -> S13
#   Reduced cost: PK334 480815
#   Allocation success: PK386 -> S13
#   Reduced cost: PK386 480815
#   Allocation success: PK455 -> S11
#   Reduced cost: PK455 480815
# 62/69
#   Allocation success: PK401 -> S4
#   Reduced cost: PK401 480815
#   Allocation success: PK497 -> S4
#   Reduced cost: PK497 480815
#   Allocation success: PK170 -> S19
#   Reduced cost: PK170 480815
#   Allocation success: PK315 -> S4
#   Reduced cost: PK315 480815
# 63/69
#   Allocation success: PK107 -> S39
#   Reduced cost: PK107 480815
#   Allocation success: PK336 -> S39
#   Reduced cost: PK336 480815
#   Allocation success: PK463 -> S34
#   Reduced cost: PK463 480815
# 64/69
#   Allocation success: PK262 -> T21
#   Reduced cost: PK262 480815
#   Allocation success: PK375 -> T22
#   Reduced cost: PK375 480815
#   Allocation success: PK285 -> T7
#   Reduced cost: PK285 480815
#   Allocation success: PK434 -> T21
#   Reduced cost: PK434 480815
#   Allocation success: PK467 -> T7
#   Reduced cost: PK467 480815
# 65/69
#   Allocation success: PK293 -> S4
#   Reduced cost: PK293 480815
#   Allocation success: PK424 -> S4
#   Reduced cost: PK424 480815
#   Allocation success: PK180 -> S19
#   Reduced cost: PK180 480815
#   Allocation success: PK488 -> S19
#   Reduced cost: PK488 480815
# 66/69
#   Allocation success: PK196 -> S4
#   Reduced cost: PK196 480815
#   Allocation success: PK422 -> S19
#   Reduced cost: PK422 480815
# 67/69
#   Allocation success: PK344 -> S12
#   Reduced cost: PK344 480815
#   Allocation success: PK391 -> S12
#   Reduced cost: PK391 480815
#   Allocation success: PK292 -> S12
#   Reduced cost: PK292 480815
#   Allocation success: PK261 -> S11
#   Reduced cost: PK261 480815
#   Allocation success: PK144 -> S11
#   Reduced cost: PK144 480815
# 68/69
#   Allocation success: PK458 -> S38
#   Reduced cost: PK458 480815
# 69/69
#   Allocation success: PK171 -> S15
#   Reduced cost: PK171 480815
#   Allocation success: PK390 -> S19
#   Reduced cost: PK390 480815
#   Allocation success: PK264 -> S15
#   Reduced cost: PK264 480815
#
# Total reduced: 231
# Final cost: 480815
# ========================================
# No conflict found!
# Total allocation: 235
# Real Total allocation: 235
# Used gates: 67
# ========================================
# ========================================
# No conflict found!
# Total allocation: 235
# Real Total allocation: 235
# Used gates: 67
# ========================================
# 1/69
# 2/69
# 3/69
#   Allocation success: PK458 -> S38
#   Reduced gate: S38
# 4/69
# 5/69
# 6/69
#   Allocation success: PK373 -> S41
# 7/69
#   Allocation success: PK107 -> S34
#   Allocation success: PK336 -> T4
# 8/69
#   Allocation success: PK308 -> S36
# 9/69
#   Allocation success: PK328 -> T6
# 10/69
#   Allocation success: PK347 -> S37
# 11/69
# 12/69
#   Allocation success: PK363 -> T2
# 13/69
#   Allocation success: PK331 -> T24
# 14/69
#   Allocation success: PK352 -> T25
# 15/69
# 16/69
#   Allocation success: PK382 -> T26
# 17/69
# 18/69
# 19/69
#   Allocation success: PK338 -> S31
# 20/69
#   Allocation success: PK340 -> T3
# 21/69
#   Allocation success: PK333 -> T27
# 22/69
# 23/69
#   Allocation success: PK400 -> S40
# 24/69
# 25/69
#   Allocation success: PK104 -> S34
# 26/69
#   Allocation success: PK315 -> S4
# 27/69
#   Allocation success: PK320 -> S16
# 28/69
#   Allocation success: PK348 -> S16
# 29/69
#   Allocation success: PK360 -> T13
# 30/69
#   Allocation success: PK131 -> T28
#   Allocation success: PK377 -> T28
# 31/69
#   Allocation success: PK297 -> S8
# 32/69
#   Allocation success: PK276 -> S24
# 33/69
#   Allocation success: PK280 -> T24
#   Allocation success: PK374 -> T24
# 34/69
#   Allocation success: PK266 -> T11
# 35/69
#   Allocation success: PK293 -> S8
# 36/69
#   Allocation success: PK272 -> T12
# 37/69
#   Allocation success: PK171 -> S15
#   Allocation success: PK264 -> S15
# 38/69
#   Allocation success: PK129 -> T4
#   Allocation success: PK304 -> T4
#   Allocation success: PK370 -> T4
# 39/69
#   Allocation success: PK309 -> S21
#   Allocation success: PK170 -> S21
# 40/69
#   Allocation success: PK108 -> S35
#   Allocation success: PK411 -> S35
#   Allocation success: PK316 -> S35
# 41/69
#   Allocation success: PK187 -> S1
#   Allocation success: PK291 -> T10
# 42/69
#   Allocation success: PK274 -> S11
# 43/69
#   Allocation success: PK298 -> S8
#   Allocation success: PK443 -> S5
# 44/69
#   Allocation success: PK106 -> T23
#   Allocation success: PK452 -> T24
#   Allocation success: PK349 -> T23
# 45/69
#   Allocation success: PK279 -> T16
#   Allocation success: PK346 -> S17
# 46/69
#   Allocation success: PK428 -> S8
#   Allocation success: PK192 -> S8
# 47/69
# 48/69
#   Allocation success: PK440 -> S1
#   Allocation success: PK180 -> S1
# 49/69
#   Allocation success: PK300 -> S8
#   Allocation success: PK447 -> S23
#   Allocation success: PK273 -> S23
# 50/69
#   Allocation success: PK305 -> S8
#   Allocation success: PK150 -> S26
#   Allocation success: PK355 -> S26
# 51/69
#   Allocation success: PK288 -> S14
#   Allocation success: PK335 -> S14
#   Allocation success: PK117 -> S14
# 52/69
#   Allocation success: PK362 -> T15
#   Allocation success: PK182 -> T15
#   Allocation success: PK282 -> T15
# 53/69
#   Allocation success: PK433 -> T14
#   Allocation success: PK310 -> S8
#   Allocation success: PK136 -> T14
# 54/69
#   Allocation success: PK429 -> S18
#   Allocation success: PK312 -> S18
#   Allocation success: PK147 -> S18
# 55/69
#   Allocation success: PK439 -> S9
#   Allocation success: PK179 -> S9
#   Allocation success: PK299 -> S25
# 56/69
# 57/69
#   Allocation success: PK294 -> T18
#   Allocation success: PK339 -> T18
#   Allocation success: PK267 -> T18
# 58/69
#   Allocation success: PK431 -> S3
#   Allocation success: PK173 -> S3
#   Allocation success: PK307 -> S25
# 59/69
#   Allocation success: PK438 -> S22
#   Allocation success: PK306 -> S8
#   Allocation success: PK442 -> S1
# 60/69
# 61/69
# 62/69
#   Allocation success: PK149 -> S12
# 63/69
# 64/69
# 65/69
# 66/69
#   Allocation success: PK437 -> S2
#   Allocation success: PK277 -> S2
#   Allocation success: PK175 -> S2
#   Allocation success: PK326 -> S2
# 67/69
#   Allocation success: PK430 -> S20
#   Allocation success: PK323 -> S20
#   Allocation success: PK188 -> S20
#   Allocation success: PK283 -> S20
# 68/69
#   Allocation success: PK144 -> S12
# 69/69
#   Allocation success: PK435 -> S6
#   Allocation success: PK284 -> S6
#   Allocation success: PK325 -> S6
#   Allocation success: PK446 -> S6
#
# Total reduced gates: 1
# ========================================
# No conflict found!
# Total allocation: 235
# Real Total allocation: 235
# Used gates: 66
# ========================================

# %%
imp.reload(Alg3)
# 问题三算法
alloc3A = Alg3.algorithmA(Table, flight, graph, graphPi, alloc2)
alloc3 = Alg3.algorithmB(Table, flight, graph, graphPi, alloc3A)
# Out:
# Import alg2 module at 2018-09-20 10:42:32.755080
# ========================================
# No conflict found!
# Total allocation: 235
# Real Total allocation: 235
# Used gates: 66
# ========================================
# 0.19815289434
# 1/69
#   Allocation success: PK107 -> S39
#   Reduced cost: PK107 0.19815289434
#   Allocation success: PK461 -> S39
#   Reduced cost: PK461 0.19815289434
#   Allocation success: PK336 -> S39
#   Reduced cost: PK336 0.19815289434
# 2/69
#   Allocation success: PK104 -> S39
#   Reduced cost: PK104 0.19815289434
#   Allocation success: PK458 -> S39
#   Reduced cost: PK458 0.19815289434
# 3/69
#   Allocation success: PK315 -> S19
#   Reduced cost: PK315 0.19815289434
#   Allocation success: PK390 -> S19
#   Reduced cost: PK390 0.19815289434
#   Allocation success: PK488 -> S19
#   Reduced cost: PK488 0.19815289434
# 4/69
#   Allocation success: PK196 -> S19
#   Reduced cost: PK196 0.19815289434
#   Allocation success: PK422 -> S19
#   Reduced cost: PK422 0.19815289434
# 5/69
#   Allocation success: PK102 -> S4
#   Reduced cost: PK102 0.19815289434
#   Allocation success: PK348 -> S19
#   Reduced cost: PK348 0.19815289434
#   Allocation success: PK415 -> S4
#   Reduced cost: PK415 0.19815289434
# 6/69
#   Allocation success: PK468 -> S39
#   Reduced cost: PK468 0.19815289434
#   Allocation success: PK370 -> S34
#   Reduced cost: PK370 0.19815289434
#   Allocation success: PK129 -> S34
#   Reduced cost: PK129 0.19815289434
#   Allocation success: PK304 -> S39
#   Reduced cost: PK304 0.19815289434
# 7/69
#   Allocation success: PK417 -> S4
#   Reduced cost: PK417 0.19815289434
#   Allocation success: PK360 -> S4
#   Reduced cost: PK360 0.19815289434
#   Allocation success: PK145 -> S4
#   Reduced cost: PK145 0.19815289434
# 8/69
# 9/69
#   Allocation success: PK490 -> S4
#   Reduced cost: PK490 0.19815289434
#   Allocation success: PK459 -> T8
#   Reduced cost: PK459 0.19815289434
#   Allocation success: PK321 -> T8
#   Reduced cost: PK321 0.19815289434
#   Allocation success: PK427 -> T8
#   Reduced cost: PK427 0.19815289434
#   Allocation success: PK375 -> T7
#   Reduced cost: PK375 0.19815289434
#   Allocation success: PK278 -> T8
#   Reduced cost: PK278 0.19815289434
# 10/69
#   Allocation success: PK466 -> S39
#   Reduced cost: PK466 0.19815289434
#   Allocation success: PK108 -> S34
#   Reduced cost: PK108 0.19815289434
#   Allocation success: PK316 -> S39
#   Reduced cost: PK316 0.19815289434
#   Allocation success: PK411 -> S39
#   Reduced cost: PK411 0.19815289434
# 11/69
#   Allocation success: PK131 -> S34
#   Reduced cost: PK131 0.19815289434
#   Allocation success: PK464 -> S34
#   Reduced cost: PK464 0.19815289434
#   Allocation success: PK377 -> S39
#   Reduced cost: PK377 0.19815289434
# 12/69
#   Allocation success: PK300 -> S19
#   Reduced cost: PK300 0.19815289434
#   Allocation success: PK447 -> S19
#   Reduced cost: PK447 0.19815289434
#   Allocation success: PK273 -> S4
#   Reduced cost: PK273 0.19815289434
#   Allocation success: PK410 -> S4
#   Reduced cost: PK410 0.19815289434
# 13/69
#   Allocation success: PK400 -> S39
#   Reduced cost: PK400 0.19815289434
#   Allocation success: PK208 -> S40
#   Reduced cost: PK208 0.19815289434
# 14/69
#   Allocation success: PK479 -> S19
#   Reduced cost: PK479 0.19815289434
#   Allocation success: PK355 -> S19
#   Reduced cost: PK355 0.19815289434
#   Allocation success: PK403 -> S19
#   Reduced cost: PK403 0.19815289434
#   Allocation success: PK150 -> S4
#   Reduced cost: PK150 0.19815289434
#   Allocation success: PK305 -> S19
#   Reduced cost: PK305 0.19815289434
# 15/69
#   Allocation success: PK449 -> S34
#   Reduced cost: PK449 0.19815289434
#   Allocation success: PK328 -> S34
#   Reduced cost: PK328 0.19815289434
# 16/69
#   Allocation success: PK329 -> T22
#   Reduced cost: PK329 0.19815289434
#   Allocation success: PK286 -> T22
#   Reduced cost: PK286 0.19815289434
#   Allocation success: PK142 -> T22
#   Reduced cost: PK142 0.19815289434
#   Allocation success: PK436 -> T22
#   Reduced cost: PK436 0.19815289434
#   Allocation success: PK372 -> T22
#   Reduced cost: PK372 0.19815289434
# 17/69
#   Allocation success: PK441 -> S19
#   Reduced cost: PK441 0.19815289434
#   Allocation success: PK419 -> S4
#   Reduced cost: PK419 0.19815289434
# 18/69
#   Allocation success: PK484 -> S4
#   Reduced cost: PK484 0.19815289434
#   Allocation success: PK175 -> S19
#   Reduced cost: PK175 0.19815289434
#   Allocation success: PK277 -> S4
#   Reduced cost: PK277 0.19815289434
#   Allocation success: PK437 -> S16
#   Reduced cost: PK437 0.19815289434
#   Allocation success: PK388 -> S4
#   Reduced cost: PK388 0.19815289434
#   Allocation success: PK326 -> S19
#   Reduced cost: PK326 0.19815289434
# 19/69
#   Allocation success: PK376 -> S19
#   Reduced cost: PK376 0.19815289434
#   Allocation success: PK168 -> S19
#   Reduced cost: PK168 0.19815289434
# 20/69
#   Allocation success: PK493 -> S4
#   Reduced cost: PK493 0.19815289434
#   Allocation success: PK323 -> S19
#   Reduced cost: PK323 0.19815289434
#   Allocation success: PK188 -> S19
#   Reduced cost: PK188 0.19815289434
#   Allocation success: PK283 -> S19
#   Reduced cost: PK283 0.19815289434
#   Allocation success: PK385 -> S4
#   Reduced cost: PK385 0.19815289434
#   Allocation success: PK430 -> S19
#   Reduced cost: PK430 0.19815289434
# 21/69
#   Allocation success: PK117 -> S4
#   Reduced cost: PK117 0.19815289434
#   Allocation success: PK489 -> S19
#   Reduced cost: PK489 0.19815289434
#   Allocation success: PK288 -> S19
#   Reduced cost: PK288 0.19815289434
#   Allocation success: PK335 -> S19
#   Reduced cost: PK335 0.19815289434
#   Allocation success: PK392 -> S14
#   Reduced cost: PK392 0.19815289434
# 22/69
#   Allocation success: PK412 -> S4
#   Reduced cost: PK412 0.19815289434
#   Allocation success: PK496 -> S4
#   Reduced cost: PK496 0.19815289434
#   Allocation success: PK362 -> S19
#   Reduced cost: PK362 0.19815289434
#   Allocation success: PK182 -> S19
#   Reduced cost: PK182 0.19815289434
#   Allocation success: PK282 -> T15
#   Reduced cost: PK282 0.19815289434
# 23/69
#   Allocation success: PK347 -> S34
#   Reduced cost: PK347 0.19815289434
#   Allocation success: PK159 -> S34
#   Reduced cost: PK159 0.19815289434
# 24/69
#   Allocation success: PK500 -> S4
#   Reduced cost: PK500 0.19815289434
#   Allocation success: PK443 -> S4
#   Reduced cost: PK443 0.19815289434
#   Allocation success: PK298 -> S4
#   Reduced cost: PK298 0.19815289434
#   Allocation success: PK408 -> S4
#   Reduced cost: PK408 0.19815289434
# 25/69
#   Allocation success: PK433 -> S4
#   Reduced cost: PK433 0.19815289434
#   Allocation success: PK380 -> S4
#   Reduced cost: PK380 0.19815289434
#   Allocation success: PK310 -> S19
#   Reduced cost: PK310 0.19815289434
#   Allocation success: PK498 -> S4
#   Reduced cost: PK498 0.19815289434
#   Allocation success: PK136 -> S4
#   Reduced cost: PK136 0.19815289434
# 26/69
#   Allocation success: PK429 -> S19
#   Reduced cost: PK429 0.19815289434
#   Allocation success: PK312 -> S19
#   Reduced cost: PK312 0.19815289434
#   Allocation success: PK147 -> S4
#   Reduced cost: PK147 0.19815289434
#   Allocation success: PK501 -> S4
#   Reduced cost: PK501 0.19815289434
#   Allocation success: PK367 -> S4
#   Reduced cost: PK367 0.19815289434
# 27/69
#   Allocation success: PK477 -> S19
#   Reduced cost: PK477 0.19815289434
#   Allocation success: PK299 -> S4
#   Reduced cost: PK299 0.19815289434
#   Allocation success: PK179 -> S4
#   Reduced cost: PK179 0.19815289434
#   Allocation success: PK390 -> S4
#   Reduced cost: PK390 0.19815289434
# 28/69
#   Allocation success: PK444 -> T7
#   Reduced cost: PK444 0.19815289434
#   Allocation success: PK404 -> T9
#   Reduced cost: PK404 0.19815289434
#   Allocation success: PK296 -> T9
#   Reduced cost: PK296 0.19815289434
#   Allocation success: PK353 -> T9
#   Reduced cost: PK353 0.19815289434
#   Allocation success: PK270 -> T9
#   Reduced cost: PK270 0.19815289434
# 29/69
#   Allocation success: PK331 -> T24
#   Reduced cost: PK331 0.19815289434
#   Allocation success: PK151 -> T24
#   Reduced cost: PK151 0.19815289434
# 30/69
#   Allocation success: PK297 -> S4
#   Reduced cost: PK297 0.19815289434
#   Allocation success: PK486 -> S19
#   Reduced cost: PK486 0.19815289434
#   Allocation success: PK387 -> S19
#   Reduced cost: PK387 0.19815289434
# 31/69
# 32/69
#   Allocation success: PK279 -> S4
#   Reduced cost: PK279 0.19815289434
#   Allocation success: PK197 -> S19
#   Reduced cost: PK197 0.19815289434
#   Allocation success: PK425 -> S17
#   Reduced cost: PK425 0.19815289434
#   Allocation success: PK346 -> S4
#   Reduced cost: PK346 0.19815289434
# 33/69
#   Allocation success: PK433 -> S4
#   Reduced cost: PK433 0.19815289434
#   Allocation success: PK482 -> S4
#   Reduced cost: PK482 0.19815289434
#   Allocation success: PK396 -> S19
#   Reduced cost: PK396 0.19815289434
#   Allocation success: PK173 -> S19
#   Reduced cost: PK173 0.19815289434
#   Allocation success: PK307 -> S19
#   Reduced cost: PK307 0.19815289434
# 34/69
#   Allocation success: PK306 -> S4
#   Reduced cost: PK306 0.19815289434
#   Allocation success: PK254 -> S16
#   Reduced cost: PK254 0.19815289434
#   Allocation success: PK442 -> S16
#   Reduced cost: PK442 0.19815289434
#   Allocation success: PK356 -> S4
#   Reduced cost: PK356 0.19815289434
#   Allocation success: PK438 -> S19
#   Reduced cost: PK438 0.19815289434
# 35/69
#   Allocation success: PK156 -> T21
#   Reduced cost: PK156 0.19815289434
#   Allocation success: PK265 -> T22
#   Reduced cost: PK265 0.19815289434
#   Allocation success: PK420 -> T20
#   Reduced cost: PK420 0.19815289434
#   Allocation success: PK341 -> T7
#   Reduced cost: PK341 0.19815289434
# 36/69
#   Allocation success: PK261 -> S11
#   Reduced cost: PK261 0.19815289434
#   Allocation success: PK358 -> S11
#   Reduced cost: PK358 0.19815289434
#   Allocation success: PK421 -> S11
#   Reduced cost: PK421 0.19815289434
#   Allocation success: PK314 -> S11
#   Reduced cost: PK314 0.19815289434
#   Allocation success: PK470 -> S11
#   Reduced cost: PK470 0.19815289434
#   Allocation success: PK144 -> S11
#   Reduced cost: PK144 0.19815289434
# 37/69
#   Allocation success: PK454 -> S34
#   Reduced cost: PK454 0.19815289434
#   Allocation success: PK308 -> S34
#   Reduced cost: PK308 0.19815289434
# 38/69
#   Allocation success: PK494 -> S4
#   Reduced cost: PK494 0.19815289434
#   Allocation success: PK435 -> S4
#   Reduced cost: PK435 0.19815289434
#   Allocation success: PK446 -> S19
#   Reduced cost: PK446 0.19815289434
#   Allocation success: PK325 -> S4
#   Reduced cost: PK325 0.19815289434
#   Allocation success: PK284 -> S19
#   Reduced cost: PK284 0.19815289434
#   Allocation success: PK383 -> S4
#   Reduced cost: PK383 0.19815289434
# 39/69
#   Allocation success: PK259 -> S16
#   Reduced cost: PK259 0.19815289434
#   Allocation success: PK414 -> S19
#   Reduced cost: PK414 0.19815289434
#   Allocation success: PK187 -> S16
#   Reduced cost: PK187 0.19815289434
# 40/69
#   Allocation success: PK089 -> T2
#   Reduced cost: PK089 0.19815289434
#   Allocation success: PK363 -> S39
#   Reduced cost: PK363 0.19815289434
# 41/69
#   Allocation success: PK258 -> T22
#   Reduced cost: PK258 0.19815289434
#   Allocation success: PK177 -> T22
#   Reduced cost: PK177 0.19815289434
#   Allocation success: PK434 -> T22
#   Reduced cost: PK434 0.19815289434
#   Allocation success: PK378 -> T21
#   Reduced cost: PK378 0.19815289434
#   Allocation success: PK337 -> T21
#   Reduced cost: PK337 0.19815289434
# 42/69
#   Allocation success: PK452 -> T24
#   Reduced cost: PK452 0.19815289434
#   Allocation success: PK349 -> S34
#   Reduced cost: PK349 0.19815289434
#   Allocation success: PK487 -> T23
#   Reduced cost: PK487 0.19815289434
#   Allocation success: PK106 -> T24
#   Reduced cost: PK106 0.19815289434
# 43/69
#   Allocation success: PK339 -> S4
#   Reduced cost: PK339 0.19815289434
#   Allocation success: PK181 -> S4
#   Reduced cost: PK181 0.19815289434
#   Allocation success: PK399 -> S4
#   Reduced cost: PK399 0.19815289434
#   Allocation success: PK294 -> S19
#   Reduced cost: PK294 0.19815289434
# 44/69
#   Allocation success: PK346 -> S24
#   Reduced cost: PK346 0.19815289434
#   Allocation success: PK174 -> S4
#   Reduced cost: PK174 0.19815289434
#   Allocation success: PK276 -> S4
#   Reduced cost: PK276 0.19815289434
#   Allocation success: PK423 -> S4
#   Reduced cost: PK423 0.19815289434
# 45/69
#   Allocation success: PK445 -> T25
#   Reduced cost: PK445 0.19815289434
#   Allocation success: PK352 -> T25
#   Reduced cost: PK352 0.19815289434
# 46/69
#   Allocation success: PK457 -> S33
#   Reduced cost: PK457 0.19815289434
# 47/69
#   Allocation success: PK193 -> S4
#   Reduced cost: PK193 0.19815289434
#   Allocation success: PK418 -> S4
#   Reduced cost: PK418 0.19815289434
# 48/69
#   Allocation success: PK448 -> S4
#   Reduced cost: PK448 0.19815289434
#   Allocation success: PK355 -> S19
#   Reduced cost: PK355 0.19815289434
#   Allocation success: PK407 -> S4
#   Reduced cost: PK407 0.19815289434
#   Allocation success: PK277 -> S4
#   Reduced cost: PK277 0.19815289434
#   Allocation success: PK310 -> S19
#   Reduced cost: PK310 0.19815289434
# 49/69
#   Allocation success: PK107 -> S39
#   Reduced cost: PK107 0.19815289434
#   Allocation success: PK471 -> S34
#   Reduced cost: PK471 0.19815289434
#   Allocation success: PK382 -> S39
#   Reduced cost: PK382 0.19815289434
# 50/69
#   Allocation success: PK409 -> S11
#   Reduced cost: PK409 0.19815289434
#   Allocation success: PK274 -> T1
#   Reduced cost: PK274 0.19815289434
#   Allocation success: PK465 -> S12
#   Reduced cost: PK465 0.19815289434
#   Allocation success: PK318 -> T1
#   Reduced cost: PK318 0.19815289434
# 51/69
#   Allocation success: PK280 -> T24
#   Reduced cost: PK280 0.19815289434
#   Allocation success: PK331 -> T24
#   Reduced cost: PK331 0.19815289434
# 52/69
#   Allocation success: PK369 -> S19
#   Reduced cost: PK369 0.19815289434
#   Allocation success: PK155 -> S4
#   Reduced cost: PK155 0.19815289434
#   Allocation success: PK266 -> S19
#   Reduced cost: PK266 0.19815289434
# 53/69
#   Allocation success: PK394 -> S4
#   Reduced cost: PK394 0.19815289434
#   Allocation success: PK473 -> S19
#   Reduced cost: PK473 0.19815289434
# 54/69
#   Allocation success: PK191 -> S4
#   Reduced cost: PK191 0.19815289434
#   Allocation success: PK267 -> S19
#   Reduced cost: PK267 0.19815289434
#   Allocation success: PK413 -> S4
#   Reduced cost: PK413 0.19815289434
# 55/69
#   Allocation success: PK338 -> S31
#   Reduced cost: PK338 0.19815289434
#   Allocation success: PK094 -> S31
#   Reduced cost: PK094 0.19815289434
# 56/69
#   Allocation success: PK456 -> S34
#   Reduced cost: PK456 0.19815289434
#   Allocation success: PK340 -> S39
#   Reduced cost: PK340 0.19815289434
# 57/69
#   Allocation success: PK333 -> T26
#   Reduced cost: PK333 0.19815289434
#   Allocation success: PK460 -> S39
#   Reduced cost: PK460 0.19815289434
# 58/69
#   Allocation success: PK364 -> S4
#   Reduced cost: PK364 0.19815289434
#   Allocation success: PK491 -> S16
#   Reduced cost: PK491 0.19815289434
#   Allocation success: PK192 -> S4
#   Reduced cost: PK192 0.19815289434
#   Allocation success: PK293 -> S19
#   Reduced cost: PK293 0.19815289434
#   Allocation success: PK428 -> S19
#   Reduced cost: PK428 0.19815289434
# 59/69
#   Allocation success: PK463 -> S34
#   Reduced cost: PK463 0.19815289434
# 60/69
#   Allocation success: PK195 -> S25
#   Reduced cost: PK195 0.19815289434
#   Allocation success: PK272 -> S19
#   Reduced cost: PK272 0.19815289434
#   Allocation success: PK406 -> S19
#   Reduced cost: PK406 0.19815289434
# 61/69
#   Allocation success: PK287 -> S13
#   Reduced cost: PK287 0.19815289434
#   Allocation success: PK334 -> S13
#   Reduced cost: PK334 0.19815289434
#   Allocation success: PK386 -> S13
#   Reduced cost: PK386 0.19815289434
#   Allocation success: PK475 -> S11
#   Reduced cost: PK475 0.19815289434
# 62/69
#   Allocation success: PK339 -> S19
#   Reduced cost: PK339 0.19815289434
#   Allocation success: PK196 -> S19
#   Reduced cost: PK196 0.19815289434
#   Allocation success: PK395 -> S4
#   Reduced cost: PK395 0.19815289434
# 63/69
#   Allocation success: PK453 -> S34
#   Reduced cost: PK453 0.19815289434
#   Allocation success: PK108 -> S39
#   Reduced cost: PK108 0.19815289434
#   Allocation success: PK373 -> S39
#   Reduced cost: PK373 0.19815289434
# 64/69
#   Allocation success: PK262 -> T7
#   Reduced cost: PK262 0.19815289434
#   Allocation success: PK444 -> T7
#   Reduced cost: PK444 0.19815289434
#   Allocation success: PK341 -> T22
#   Reduced cost: PK341 0.19815289434
#   Allocation success: PK432 -> T21
#   Reduced cost: PK432 0.19815289434
#   Allocation success: PK285 -> T7
#   Reduced cost: PK285 0.19815289434
# 65/69
#   Allocation success: PK401 -> S4
#   Reduced cost: PK401 0.19815289434
#   Allocation success: PK273 -> S19
#   Reduced cost: PK273 0.19815289434
#   Allocation success: PK440 -> S19
#   Reduced cost: PK440 0.19815289434
#   Allocation success: PK168 -> S4
#   Reduced cost: PK168 0.19815289434
#   Allocation success: PK315 -> S19
#   Reduced cost: PK315 0.19815289434
# 66/69
#   Allocation success: PK478 -> S4
#   Reduced cost: PK478 0.19815289434
#   Allocation success: PK424 -> S4
#   Reduced cost: PK424 0.19815289434
# 67/69
#   Allocation success: PK358 -> S12
#   Reduced cost: PK358 0.19815289434
#   Allocation success: PK421 -> S11
#   Reduced cost: PK421 0.19815289434
#   Allocation success: PK314 -> S11
#   Reduced cost: PK314 0.19815289434
#   Allocation success: PK149 -> S11
#   Reduced cost: PK149 0.19815289434
#   Allocation success: PK470 -> S11
#   Reduced cost: PK470 0.19815289434
# 68/69
#   Allocation success: PK458 -> S38
#   Reduced cost: PK458 0.19815289434
# 69/69
#   Allocation success: PK171 -> S4
#   Reduced cost: PK171 0.19815289434
#   Allocation success: PK398 -> S4
#   Reduced cost: PK398 0.19815289434
#   Allocation success: PK264 -> S19
#   Reduced cost: PK264 0.19815289434
#
# Total reduced: 234
# Final cost: 0.19815289434
# ========================================
# No conflict found!
# Total allocation: 235
# Real Total allocation: 235
# Used gates: 67
# ========================================
# ========================================
# No conflict found!
# Total allocation: 235
# Real Total allocation: 235
# Used gates: 67
# ========================================
# 1/69
# 2/69
# 3/69
#   Allocation success: PK308 -> S36
#   Reduced gate: S36
# 4/69
# 5/69
# 6/69
# 7/69
#   Allocation success: PK108 -> T26
#   Allocation success: PK308 -> T26
# 8/69
#   Allocation success: PK377 -> T6
# 9/69
#   Allocation success: PK328 -> S37
# 10/69
#   Allocation success: PK349 -> T2
# 11/69
#   Allocation success: PK374 -> T24
# 12/69
#   Allocation success: PK352 -> T25
# 13/69
#   Allocation success: PK174 -> T16
# 14/69
#   Allocation success: PK168 -> T11
# 15/69
#   Allocation success: PK448 -> S7
# 16/69
#   Allocation success: PK338 -> S31
# 17/69
#   Allocation success: PK382 -> T3
# 18/69
#   Allocation success: PK363 -> T27
# 19/69
#   Allocation success: PK479 -> T19
# 20/69
#   Allocation success: PK340 -> S41
# 21/69
#   Allocation success: PK347 -> S40
# 22/69
#   Allocation success: PK256 -> S1
# 23/69
#   Allocation success: PK196 -> S10
# 24/69
#   Allocation success: PK181 -> S15
# 25/69
#   Allocation success: PK107 -> T26
#   Allocation success: PK373 -> T26
# 26/69
#   Allocation success: PK259 -> S8
#   Allocation success: PK187 -> S8
# 27/69
#   Allocation success: PK129 -> T4
#   Allocation success: PK336 -> T4
# 28/69
#   Allocation success: PK348 -> T13
#   Allocation success: PK102 -> T13
# 29/69
#   Allocation success: PK195 -> S21
#   Allocation success: PK272 -> S21
# 30/69
#   Allocation success: PK411 -> T28
#   Allocation success: PK316 -> T28
# 31/69
#   Allocation success: PK441 -> S15
# 32/69
#   Allocation success: PK326 -> S28
#   Allocation success: PK145 -> S28
# 33/69
#   Allocation success: PK104 -> T26
#   Allocation success: PK333 -> T26
# 34/69
#   Allocation success: PK280 -> T24
#   Allocation success: PK331 -> T24
# 35/69
#   Allocation success: PK266 -> T17
#   Allocation success: PK155 -> S15
# 36/69
#   Allocation success: PK428 -> T12
#   Allocation success: PK193 -> T12
# 37/69
#   Allocation success: PK339 -> S4
#   Allocation success: PK171 -> S16
#   Allocation success: PK264 -> S15
# 38/69
#   Allocation success: PK293 -> S16
#   Allocation success: PK355 -> S16
#   Allocation success: PK473 -> T10
# 39/69
#   Allocation success: PK131 -> S35
#   Allocation success: PK304 -> S35
#   Allocation success: PK370 -> S35
# 40/69
#   Allocation success: PK307 -> T10
#   Allocation success: PK442 -> T10
#   Allocation success: PK254 -> T10
# 41/69
#   Allocation success: PK274 -> T1
# 42/69
#   Allocation success: PK117 -> T15
#   Allocation success: PK498 -> T15
#   Allocation success: PK282 -> T15
# 43/69
#   Allocation success: PK136 -> S18
#   Allocation success: PK297 -> S18
#   Allocation success: PK497 -> S18
# 44/69
#   Allocation success: PK180 -> S9
#   Allocation success: PK299 -> S9
#   Allocation success: PK476 -> S9
# 45/69
#   Allocation success: PK106 -> T24
#   Allocation success: PK452 -> T24
#   Allocation success: PK400 -> T23
# 46/69
#   Allocation success: PK325 -> T18
#   Allocation success: PK170 -> T18
#   Allocation success: PK494 -> T18
# 47/69
#   Allocation success: PK294 -> S24
#   Allocation success: PK197 -> S24
#   Allocation success: PK346 -> T16
# 48/69
#   Allocation success: PK310 -> S25
#   Allocation success: PK192 -> S25
#   Allocation success: PK491 -> S25
# 49/69
# 50/69
#   Allocation success: PK440 -> S4
#   Allocation success: PK315 -> S4
#   Allocation success: PK273 -> S4
#   Allocation success: PK478 -> S4
# 51/69
#   Allocation success: PK300 -> S26
#   Allocation success: PK147 -> S26
#   Allocation success: PK500 -> S26
# 52/69
#   Allocation success: PK439 -> S2
#   Allocation success: PK305 -> S2
#   Allocation success: PK150 -> S2
#   Allocation success: PK486 -> S2
# 53/69
#   Allocation success: PK447 -> S14
#   Allocation success: PK288 -> S14
#   Allocation success: PK335 -> S14
#   Allocation success: PK493 -> S14
# 54/69
#   Allocation success: PK431 -> S5
#   Allocation success: PK188 -> S5
#   Allocation success: PK298 -> S5
#   Allocation success: PK489 -> S5
# 55/69
# 56/69
#   Allocation success: PK438 -> S3
#   Allocation success: PK179 -> S3
#   Allocation success: PK482 -> S3
#   Allocation success: PK279 -> S3
# 57/69
#   Allocation success: PK433 -> S22
#   Allocation success: PK306 -> S22
#   Allocation success: PK267 -> S21
#   Allocation success: PK191 -> S22
# 58/69
# 59/69
#   Allocation success: PK435 -> S6
#   Allocation success: PK446 -> S6
#   Allocation success: PK501 -> S6
#   Allocation success: PK291 -> S6
# 60/69
# 61/69
#   Allocation success: PK312 -> S27
#   Allocation success: PK173 -> S27
#   Allocation success: PK277 -> S27
#   Allocation success: PK477 -> S27
# 62/69
#   Allocation success: PK144 -> S12
# 63/69
#   Allocation success: PK488 -> T8
# 64/69
# 65/69
# 66/69
#   Allocation success: PK437 -> S20
#   Allocation success: PK323 -> S20
#   Allocation success: PK283 -> S20
#   Allocation success: PK175 -> S20
#   Allocation success: PK484 -> S20
# 67/69
#   Allocation success: PK430 -> T14
#   Allocation success: PK284 -> T14
#   Allocation success: PK320 -> T14
#   Allocation success: PK443 -> T14
#   Allocation success: PK496 -> T14
# 68/69
#   Allocation success: PK429 -> S17
#   Allocation success: PK309 -> S17
#   Allocation success: PK276 -> S17
#   Allocation success: PK182 -> S17
#   Allocation success: PK490 -> S17
# 69/69
#   Allocation success: PK149 -> S12
#
# Total reduced gates: 1
# ========================================
# No conflict found!
# Total allocation: 235
# Real Total allocation: 235
# Used gates: 66
# ========================================

# %%
# 题一算法结果画图
puckalloc1 = getpalloc(alloc1)
plot.plot_alg1(Table, alloc1, puckalloc1)

# 对于题二三算法结果，建立令有中转时间和紧张度等数据的图
cgraph = Util.CostGraph(Table, flight, getpalloc(alloc2))
plot.plot_alg23(Table, cgraph, 2)

cgraph = Util.CostGraph(Table, flight, getpalloc(alloc3))
plot.plot_alg23(Table, cgraph, 3)

# 分配结果导出csv文件
# alloc1C, alloc2, alloc3 分别是三个题的分配结果
Data.savecsv(Table, alloc1, alloc2, alloc3)
# Out:
# Fair Count: 0, rate: 0.0
# Fair Count: 0, rate: 0.0
# saving to csv file,  2018-09-20 10:42:56.842860
